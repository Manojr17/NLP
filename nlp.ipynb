# %%
pip install PyPDF2==1.26.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2

data= open("C:\\manoj\\OneDrive\\Documents\\summer1.pdf","rb")
reader = PyPDF2.PdfFileReader(data)
data
# Out:
# <_io.BufferedReader name='C:\\manoj\\OneDrive\\Documents\\summer1.pdf'>

# %%
print (reader.numPages)
# Out:
# 26

# %%
page = reader.getPage(0)

# %%
print(page.extractText())
data.close()
# Out:
# 1
#
#
#
# TABLE OF CONTENTS
#
#
# 1. Executive Summary
# ---------------------------------------------------------------
#
# 3
#
# 2. Project Overview
# -----
# -------------------------------
# -------------------------------
#
# 3
#
# 3. Objectives
# --------------------------------------------
# -------------------------------
#
# 6
#
# 4. Scope of the Project
# ---------------------------------------------------------
# -------
#
# 9
#
# 5. Methodology
# -----------------------------------------------------------------
# --------
#
# 1
# 1
#
#
# -
#
# Tools Used
# ------------------
# ------------------------
# --
# ----------------------------
#
#
#
# -
#
# Process Workflow
# -------------------------------------------------------------
# --
#
# 6. Detailed Content Analysis
# -------------------------
# -----------------------------
#
# 15
#
#
# -
#
# Breakdown of Leg
# al Topics
# -------
# ------------------------------------------------
#
#
#
# -
#
# ...

# %% [markdown]
# ## Working with text file in python

# %%
text_data = open("C:\\manoj\\OneDrive\\Documents\\summerintern.pdf","r")
print(text_data.read())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[10], line 2
#       1 text_data = open("C:\\manoj\\OneDrive\\Documents\\summerintern.pdf","r")
# ----> 2 print(text_data.read())
#
# File ~\anaconda3\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 666: character maps to <undefined>

# %%
pip install chardet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
text_data = open("C:\\manoj\\OneDrive\\Documents\\NLP.txt","r",encoding="utf-8")
print(text_data.read())
# Out:
# Definition:
# NLP is used to make computers understand the human language.
# Techniques in NLP
# 1. Text Processing and Preprocessing In NLP
# 	Tokenization: Dividing text into smaller units, such as words or sentences.
# 	Stemming and Lemmatization: Reducing words to their base or root forms.
# 	Stopword Removal: Removing common words (like “and”, “the”, “is”) that may not carry significant meaning.
# 	Text Normalization: Standardizing text, including case normalization, removing punctuation, and correcting spelling errors.
# 2. Syntax and Parsing In NLP
# 	Part-of-Speech (POS) Tagging: Assigning parts of speech to each word in a sentence (e.g., noun, verb, adjective).
# 	Dependency Parsing: Analyzing the grammatical structure of a sentence to identify relationships between words.
# 	Constituncy Parsing: Breaking down a sentence into its constituent parts or phrases (e.g., noun phrases, verb phrases).
# 3. Semantic Analysis
# ...

# %%
with open("C:\\manoj\\OneDrive\\Documents\\NLP.txt", "r", encoding="utf-8") as file:
    content = file.read()
print(content)
# Out:
# Definition:
# NLP is used to make computers understand the human language.
# Techniques in NLP
# 1. Text Processing and Preprocessing In NLP
# 	Tokenization: Dividing text into smaller units, such as words or sentences.
# 	Stemming and Lemmatization: Reducing words to their base or root forms.
# 	Stopword Removal: Removing common words (like “and”, “the”, “is”) that may not carry significant meaning.
# 	Text Normalization: Standardizing text, including case normalization, removing punctuation, and correcting spelling errors.
# 2. Syntax and Parsing In NLP
# 	Part-of-Speech (POS) Tagging: Assigning parts of speech to each word in a sentence (e.g., noun, verb, adjective).
# 	Dependency Parsing: Analyzing the grammatical structure of a sentence to identify relationships between words.
# 	Constituncy Parsing: Breaking down a sentence into its constituent parts or phrases (e.g., noun phrases, verb phrases).
# 3. Semantic Analysis
# ...

# %% [markdown]
# # Working with csv file

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("C:\\manoj\\OneDrive\\Documents\\50_Startups.csv")
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
data.shape
# Out:
# (50, 5)

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
data.isnull().any()
# Out:
# R&D Spend          False
# Administration     False
# Marketing Spend    False
# State              False
# Profit             False
# dtype: bool

# %%
data_part=data.dropna()
data_part
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
#  #  line tokenization

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ndhan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\ndhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\ndhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\ndhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\ndhan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\ndhan\AppData\Roaming\nltk_data...
# ...

# %%
import nltk
data = "welcome to great learning!!!"
tokens = nltk.sent_tokenize(data)
print(tokens)
# Out:
# ['welcome to great learning!!', '!']

# %% [markdown]
# # word tokenization

# %%
tokens = nltk.word_tokenize(data)
print(tokens)
# Out:
# ['welcome', 'to', 'great', 'learning', '!', '!', '!']

# %% [markdown]
# # stemming

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
w = ["like" , "liking" , "likes" , "liked" ]

for i in words:
    print(i , ":" , ps.stem(i))
# Out:
# like : like
# liking : like
# likes : like
# liked : like

# %% [markdown]
# # Lemmatization

# %%
import nltk
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ndhan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmati = WordNetLemmatizer()

print("socks:" , lemmati.lemmatize("socks"))
print("sons:" , lemmati.lemmatize("sons"))
# Out:
# socks: sock
# sons: son

# %% [markdown]
# # Removing stop words

# %%
from nltk.corpus import stopwords
import nltk
nltk.download("stopwords")

data = "data science is one of the most trendind field to work with."
stop_word = set(stopwords.words("English"))
print(stopwords.words()[620:680])
data = nltk.word_tokenize(data)
stops = set (stopwords.words("English"))
for  word in data:
    if word not in stops:
        print(word)
# Out:
# ['ذال', 'راء', 'زاي', 'سين', 'شين', 'صاد', 'ضاد', 'طاء', 'ظاء', 'عين', 'غين', 'فاء', 'قاف', 'كاف', 'لام', 'ميم', 'نون', 'هاء', 'واو', 'ياء', 'همزة', 'ي', 'نا', 'ك', 'كن', 'ه', 'إياه', 'إياها', 'إياهما', 'إياهم', 'إياهن', 'إياك', 'إياكما', 'إياكم', 'إياك', 'إياكن', 'إياي', 'إيانا', 'أولالك', 'تانِ', 'تانِك', 'تِه', 'تِي', 'تَيْنِ', 'ثمّ', 'ثمّة', 'ذانِ', 'ذِه', 'ذِي', 'ذَيْنِ', 'هَؤلاء', 'هَاتانِ', 'هَاتِه', 'هَاتِي', 'هَاتَيْنِ', 'هَذا', 'هَذانِ', 'هَذِه', 'هَذِي', 'هَذَيْنِ']
# data
# science
# one
# trendind
# field
# work
# .
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ndhan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(stopwords.words("e"))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...
